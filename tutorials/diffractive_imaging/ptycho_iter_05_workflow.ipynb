# %% [markdown]
# Placeholder for a ptycho demo/tutorial showing a full workflow with experimental data.
#
# - loading data, basic visualization with virtual images, binning/cropping as necessary
# - direct ptycho/parallax for getting initial probe aberrations
# - iterative ptycho, potentially with hyperparameter optimization
#
# Stephanie Ribet, Georgios Varnavides, Arthur McCray
